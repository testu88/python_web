# %%
import pandas as pd

ft = pd.read_csv('stockerbot-export.csv', on_bad_lines='skip')

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
nltk.download('subjectivity')
nltk.download('movie_reviews')

sia = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\super\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package subjectivity to
# [nltk_data]     C:\Users\super\AppData\Roaming\nltk_data...
# [nltk_data]   Package subjectivity is already up-to-date!
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\super\AppData\Roaming\nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!

# %%
ft.head()
# Out:
#                                          image_url  \
# 0  https://pbs.twimg.com/media/F-7h_aha8AAd-bI.jpg
# 1  https://pbs.twimg.com/media/F-7nxyVWQAAC7Pc.png
# 2  https://pbs.twimg.com/media/F-7n5h1X0AAeeY7.png
# 3  https://pbs.twimg.com/media/F-7oZjbXgAAKIrh.png
# 4  https://pbs.twimg.com/media/F-7qKyIaIAAVhRX.png
#
#                                      proxy_image_url image_dimensions  \
# 0  https://images-ext-1.discordapp.net/external/W...      (649, 1200)
# 1  https://images-ext-1.discordapp.net/external/N...      (1200, 573)
# 2  https://images-ext-1.discordapp.net/external/R...      (1200, 573)
# 3  https://images-ext-1.discordapp.net/external/Y...      (1200, 578)
# 4  https://images-ext-1.discordapp.net/external/k...      (1200, 589)
#
#                                        thumbnail_url  \
# 0  https://pbs.twimg.com/profile_images/154295574...
# 1  https://pbs.twimg.com/profile_images/164958768...
# 2  https://pbs.twimg.com/profile_images/164958768...
# 3  https://pbs.twimg.com/profile_images/164958768...
# 4  https://pbs.twimg.com/profile_images/135635956...
#
#                                  proxy_thumbnail_url thumbnail_dimensions  \
# 0  https://images-ext-1.discordapp.net/external/S...             (48, 48)
# 1  https://images-ext-1.discordapp.net/external/l...             (48, 48)
# 2  https://images-ext-1.discordapp.net/external/l...             (48, 48)
# 3  https://images-ext-1.discordapp.net/external/l...             (48, 48)
# 4  https://images-ext-1.discordapp.net/external/Q...             (48, 48)
#
#                           timestamp  \
# 0  2023-11-14T23:06:39.390000+00:00
# 1  2023-11-14T23:31:41.017000+00:00
# 2  2023-11-14T23:31:45.447000+00:00
# 3  2023-11-14T23:36:39.449000+00:00
# 4  2023-11-14T23:46:39.487000+00:00
#
#                                          description  \
# 0  Crazy that $PRIME is going to >$1B market cap ...
# 1  Crazy part is, a lot of what I have been tradi...
# 2                     $AVAX\n\nStacking on support..
# 3                                      $SOL\n\nLFG!!
# 4  $INJ - Twitter been super bullish on this one ...
#
#                                                  url  \
# 0  https://twitter.com/user/status/17245642086025...
# 1  https://twitter.com/user/status/17245705594498...
# 2  https://twitter.com/user/status/17245707437976...
# 3  https://twitter.com/user/status/17245712393085...
# 4  https://twitter.com/user/status/17245734559649...
#
#                                          embed_title tweet_type  \
# 0              Crypto Mikey tweeted about PRIME, AXS      tweet
# 1  Don't follow Shardi B If You Hate Money tweete...      tweet
# 2  Don't follow Shardi B If You Hate Money tweete...      tweet
# 3  Don't follow Shardi B If You Hate Money tweete...      tweet
# 4                     IncomeSharks tweeted about INJ      tweet
#
#                                       financial_info sentiment
# 0  [{'ticker': '$PRIME', 'exchanges': [], 'price'...   Bullish
# 1  [{'ticker': '$MATIC', 'exchanges': ['binance',...   Bullish
# 2  [{'ticker': '$AVAX', 'exchanges': ['kucoin', '...   Bullish
# 3  [{'ticker': '$SOL', 'exchanges': ['kucoin', 'b...   Bullish
# 4  [{'ticker': '$INJ', 'exchanges': ['binance', '...   Bullish

# %%
ft.describe()
# Out:
#                  id
# count  2.826400e+04
# mean   1.018834e+18
# std    9.911911e+14
# min    9.671094e+17
# 25%    1.018364e+18
# 50%    1.019222e+18
# 75%    1.019585e+18
# max    1.019743e+18

# %%
ft['symbols'].value_counts()
# Out:
# symbols
# NFLX             101
# HON              100
# GPS              100
# MTB              100
# MOMO             100
#                 ...
# ORCL               1
# FB-GOOGL-GOOG      1
# INTC-USB           1
# AMZN-GPS           1
# TWTR               1
# Name: count, Length: 453, dtype: int64

# %%
nt = ft[ft['symbols']== 'NFLX']
nt_sorted = nt.sort_values(by='timestamp')
# Out:
#                         id                                               text  \
# 26216  1019690098236055600  Netflix $NFLX just released quarterly 10-Q.  Q...
# 26223  1019690300187533300  RT @blackbullforex: Excluding FAANG Stocks The...
# 26236  1019690538398707700  RT @RampCapitalLLC: Here is where $FANG was tr...
# 26239  1019690604559851500  RT @SevenPointsCap: Trader Takeaways 7.18.18 b...
# 26241  1019690654383759400  #NASDAQ MOST VOLUME  $HMNY -9.09% [Volume: +82...
# ...                    ...                                                ...
# 28026  1019726442689638400  RT @TopTickrs: $NFLX Long Trending Chart 2018-...
# 28066  1019727237296414700  RT @owlmaster08: Luckily $TSLA has great user ...
# 28099  1019728080951275500  RT @the_chart_life: Kanye/Kim Christmas portfo...
# 28115  1019728237381890000  Dow up 79 $AMZN $GOOGL $NFLX $BA $TSLA $TWTR $...
# 28237  1019729800842416100  1 to 4  trade alerts with 50% to 100% profit p...
#
#                             timestamp           source symbols company_names  \
# 26216  Wed Jul 18 21:07:19 +0000 2018   Feedmeistercom    NFLX       Netflix
# 26223  Wed Jul 18 21:08:07 +0000 2018         dexoidan    NFLX       Netflix
# 26236  Wed Jul 18 21:09:03 +0000 2018       hs_traders    NFLX       Netflix
# 26239  Wed Jul 18 21:09:19 +0000 2018    clovisskyline    NFLX       Netflix
# 26241  Wed Jul 18 21:09:31 +0000 2018   Market_Scanner    NFLX       Netflix
# ...                               ...              ...     ...           ...
# 28026  Wed Jul 18 23:31:44 +0000 2018     juliusagusta    NFLX       Netflix
# 28066  Wed Jul 18 23:34:53 +0000 2018    28delayslater    NFLX       Netflix
# 28099  Wed Jul 18 23:38:14 +0000 2018  AshtonBroussard    NFLX       Netflix
# 28115  Wed Jul 18 23:38:52 +0000 2018      NaviAvatar1    NFLX       Netflix
# 28237  Wed Jul 18 23:45:04 +0000 2018  optionalarmchat    NFLX       Netflix
#
#                                                      url  verified
# 26216                                                NaN     False
# 26223                                                NaN     False
# 26236                                                NaN     False
# 26239                      http://youtu.be/MLmX7WMEBVM?a     False
# 26241  https://twitter.com/i/web/status/1019690654383...     False
# ...                                                  ...       ...
# 28026                                                NaN     False
# 28066                                                NaN     False
# 28099                                                NaN     False
# 28115  https://www.pscp.tv/w/bh_HDDQ1NDk4MjV8MU9kS3Jw...     False
# 28237                           http://ow.ly/sf0d30kY55w     False
#
# [101 rows x 8 columns]

# %%
nt = ft[ft['symbols']== 'NFLX']
nt_sorted = nt.sort_values(by='timestamp')
compound_scores = []
for index, row in nt_sorted.iterrows():
    tweet = row['text']
    analysis = sia.polarity_scores(tweet)
    compound_scores.append(analysis['compound'])

nt_sorted['sentiment_scores'] = compound_scores
nt_sorted
# Out:
#                         id                                               text  \
# 26216  1019690098236055600  Netflix $NFLX just released quarterly 10-Q.  Q...
# 26223  1019690300187533300  RT @blackbullforex: Excluding FAANG Stocks The...
# 26236  1019690538398707700  RT @RampCapitalLLC: Here is where $FANG was tr...
# 26239  1019690604559851500  RT @SevenPointsCap: Trader Takeaways 7.18.18 b...
# 26241  1019690654383759400  #NASDAQ MOST VOLUME  $HMNY -9.09% [Volume: +82...
# ...                    ...                                                ...
# 28026  1019726442689638400  RT @TopTickrs: $NFLX Long Trending Chart 2018-...
# 28066  1019727237296414700  RT @owlmaster08: Luckily $TSLA has great user ...
# 28099  1019728080951275500  RT @the_chart_life: Kanye/Kim Christmas portfo...
# 28115  1019728237381890000  Dow up 79 $AMZN $GOOGL $NFLX $BA $TSLA $TWTR $...
# 28237  1019729800842416100  1 to 4  trade alerts with 50% to 100% profit p...
#
#                             timestamp           source symbols company_names  \
# 26216  Wed Jul 18 21:07:19 +0000 2018   Feedmeistercom    NFLX       Netflix
# 26223  Wed Jul 18 21:08:07 +0000 2018         dexoidan    NFLX       Netflix
# 26236  Wed Jul 18 21:09:03 +0000 2018       hs_traders    NFLX       Netflix
# 26239  Wed Jul 18 21:09:19 +0000 2018    clovisskyline    NFLX       Netflix
# 26241  Wed Jul 18 21:09:31 +0000 2018   Market_Scanner    NFLX       Netflix
# ...                               ...              ...     ...           ...
# 28026  Wed Jul 18 23:31:44 +0000 2018     juliusagusta    NFLX       Netflix
# 28066  Wed Jul 18 23:34:53 +0000 2018    28delayslater    NFLX       Netflix
# 28099  Wed Jul 18 23:38:14 +0000 2018  AshtonBroussard    NFLX       Netflix
# 28115  Wed Jul 18 23:38:52 +0000 2018      NaviAvatar1    NFLX       Netflix
# 28237  Wed Jul 18 23:45:04 +0000 2018  optionalarmchat    NFLX       Netflix
#
#                                                      url  verified  \
# 26216                                                NaN     False
# 26223                                                NaN     False
# 26236                                                NaN     False
# 26239                      http://youtu.be/MLmX7WMEBVM?a     False
# 26241  https://twitter.com/i/web/status/1019690654383...     False
# ...                                                  ...       ...
# 28026                                                NaN     False
# 28066                                                NaN     False
# 28099                                                NaN     False
# 28115  https://www.pscp.tv/w/bh_HDDQ1NDk4MjV8MU9kS3Jw...     False
# 28237                           http://ow.ly/sf0d30kY55w     False
#
#        sentiment_scores
# 26216            0.4545
# 26223           -0.2960
# 26236            0.5719
# 26239            0.0000
# 26241            0.0000
# ...                 ...
# 28026            0.0000
# 28066            0.8750
# 28099            0.0000
# 28115            0.0000
# 28237            0.4404
#
# [101 rows x 9 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(nt_sorted['timestamp'], compound_scores)
plt.ylabel('Compound Scores')

plt.show()
